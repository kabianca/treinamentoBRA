# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
import pandas as pd

df = spark.read.csv("/FileStore/tables/retail.csv", header=True, sep=',')
df = df.toPandas()

df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>1/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>1/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>1/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>1/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>1/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>536365</td>
#       <td>22752</td>
#       <td>SET 7 BABUSHKA NESTING BOXES</td>
#       <td>2</td>
#       <td>1/12/2010 08:26</td>
#       <td>7,65</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>536365</td>
#       <td>21730</td>
#       <td>GLASS STAR FROSTED T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>1/12/2010 08:26</td>
#       <td>4,25</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>536366</td>
#       <td>22633</td>
#       <td>HAND WARMER UNION JACK</td>
#       <td>6</td>
#       <td>1/12/2010 08:28</td>
#       <td>1,85</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>536366</td>
#       <td>22632</td>
#       <td>HAND WARMER RED POLKA DOT</td>
#       <td>6</td>
#       <td>1/12/2010 08:28</td>
#       <td>1,85</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>536367</td>
#       <td>84879</td>
#       <td>ASSORTED COLOUR BIRD ORNAMENT</td>
#       <td>32</td>
#       <td>1/12/2010 08:34</td>
#       <td>1,69</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df[['customer_id', 'quantity', 'unit_price']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>quantity</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17850</td>
#       <td>6</td>
#       <td>2,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17850</td>
#       <td>6</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17850</td>
#       <td>8</td>
#       <td>2,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17850</td>
#       <td>6</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17850</td>
#       <td>6</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>12680</td>
#       <td>12</td>
#       <td>0,85</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>12680</td>
#       <td>6</td>
#       <td>2,1</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>12680</td>
#       <td>4</td>
#       <td>4,15</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>12680</td>
#       <td>4</td>
#       <td>4,15</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>12680</td>
#       <td>3</td>
#       <td>4,95</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 3 columns</p>
# </div>

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
df[['customer_id', 'quantity']]

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
df.groupby('customer_id').agg(n=('invoice_date', 'count')).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12346</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12347</td>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12348</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12349</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>12350</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4367</th>
#       <td>18280</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>4368</th>
#       <td>18281</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4369</th>
#       <td>18282</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4370</th>
#       <td>18283</td>
#       <td>756</td>
#     </tr>
#     <tr>
#       <th>4371</th>
#       <td>18287</td>
#       <td>70</td>
#     </tr>
#   </tbody>
# </table>
# <p>4372 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
df['unit_price'].max()
# Out:
# Out[12]: '99,96'
